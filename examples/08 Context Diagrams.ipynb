# %% [markdown]
# # Context Diagrams Extension
#
# We have an extension that visualizes contexts of Capella objects.
#
# The viewpoint definiton depends on the object type.
#
# The extension is external to `capellambse` library and needs to be installed separately.
#
# You may use the below command to install it or find more guidance in the backage documentation [https://dsd-dbs.github.io/capellambse-context-diagrams/]
#
# Oh, there is one more catch about it - **it requires Python verision >= 3.9**; Please let us know if this is an issue

# %%
# !pip install capellambse_context_diagrams
# Out:
# ...
#      |████████████████████████████████| 166 kB 1.8 MB/s eta 0:00:01
# ...
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# ...

# %% [markdown]
# Now that the lib is installed we can load a test model

# %%
import capellambse
model = capellambse.MelodyModel(
    "../tests/data/melodymodel/5_2/Melody Model Test.aird"
)
# Out:
# Cannot load PVMT extension: ValueError: Provided model does not have a PropertyValuePkg
# Property values are not available in this model

# %% [markdown]
# ## Logical Component Context

# %% [markdown]
# and now as the model is loaded lets have a look at a context diagram for the `School` component

# %%
cmp = model.la.all_components.by_name("Whomping Willow")
cmp.context_diagram
# Out:
# <Diagram 'Context of Whomping Willow'>

# %% [markdown]
# ## Component Exchange Context
#
# We also found it useful to spell-out the `ComponentExchange`s - this gives us a nice overview of functional interactions between the components

# %%
cmp.exchanges.by_name("Punishment").context_diagram
# Out:
# <Diagram 'Interface Context of Punishment'>

# %% [markdown]
# it also works for more complex arrangements but we dont have one in the current test model ;-)

# %% [markdown]
# ## Functional (dataflow) Context
#
# same applies for functions - we saw it useful to see what functions are dependent on an outoput of a function of interest and what inputs it needs to do what it should. We frequently use that view in documentation

# %%
fnc = model.la.all_functions.by_name("educate Wizards")
fnc.context_diagram
# Out:
# <Diagram 'Context of educate Wizards'>
